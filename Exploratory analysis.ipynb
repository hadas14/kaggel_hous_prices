# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
# %matplotlib inline

# %%
def create_total_sf(df,sf_feature_list):
    df['TotalSF'] = df['TotalBsmtSF'] + df['1stFlrSF'] + df['2ndFlrSF']

# %%
train = pd.read_csv('our_train.csv')
create_total_sf(train,[])
train[['TotalSF', 'GrLivArea','SalePrice']].corr()

# %%
ax = sns.regplot(x="TotalSF", y="GrLivArea", data=train)

# %%
ax = sns.regplot(x="TotalSF", y="SalePrice", data=train)

# %%
ax = sns.regplot(x="GrLivArea", y="SalePrice", data=train)
